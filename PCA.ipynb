# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharthbharthulwar/TERCOM/blob/master/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris 
iris = load_iris() 
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
print(iris.data.shape)
print(iris.feature_names)

print(iris.target_names)
# Out:
# (150, 4)
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
print(pca)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
X, y = iris.data, iris.target
X_proj = pca.fit_transform(X)
print(X_proj.shape)
# Out:
# (150, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt 

plt.scatter(X_proj[: ,0], X_proj[:, 1], c = y)
plt.show()

# %%
print(pca.components_)
print(pca.components_.shape)
# Out:
# [[ 0.36138659 -0.08452251  0.85667061  0.3582892 ]
#  [ 0.65658877  0.73016143 -0.17337266 -0.07548102]]
# (2, 4)

# %%
from sklearn.datasets import load_digits
digits = load_digits()
print(digits.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'images', 'DESCR'])

# %%
print(digits.data.shape)
print(digits.images.shape)
# Out:
# (1797, 64)
# (1797, 8, 8)

# %%
X, y = digits.data, digits.target
pca_digits=PCA(0.95)
X_proj = pca_digits.fit_transform(X)
print(X.shape, X_proj.shape)
# Out:
# (1797, 64) (1797, 29)

# %%
pca_digits = PCA(2)
X_proj = pca_digits.fit_transform(X)
print(np.sum(pca_digits.explained_variance_ratio_))
# Out:
# 0.2850936482369626

# %%
plt.scatter(X_proj[:, 0], X_proj[:, 1], c = y)
plt.colorbar()
plt.show()

# %%
pca_digits = PCA(64).fit(X)
plt.semilogx(np.cumsum(pca_digits.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance Retained')
plt.ylim(0, 1)
plt.show()

# %%
from sklearn.datasets import fetch_olivetti_faces
oliv = fetch_olivetti_faces()
print(oliv.keys())
print(oliv.data.shape)
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /root/scikit_learn_data
# dict_keys(['data', 'images', 'target', 'DESCR'])
# (400, 4096)

# %%
fig = plt.figure(figsize=(6, 6))
fig.subplots_adjust(left = 0, right = 1, bottom = 0, top = 1, hspace = 0.05, wspace = 0.05)

for i in range(64):
  ax = fig.add_subplot(8, 8, i + 1, xticks = [], yticks = [])
  ax.imshow(oliv.images[i], cmap = plt.cm.bone, interpolation = 'nearest')

plt.show()

# %%
X, y = oliv.data, oliv.target
pca_oliv = PCA(64)
X_proj = pca_oliv.fit_transform(X)
print(X_proj.shape)
# Out:
# (400, 64)

# %%
fig = plt.figure(figsize=(8,8)) fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05) # plot the faces, each image is 64 by 64 pixels for i in range(10): ax = fig.add_subplot(5, 5, i+1, xticks=[], yticks=[]) ax.imshow(np.reshape(pca_oliv.components_[i,:], (64,64)), cmap=plt.cm.bone, interpolation='nearest') - See more at: https://shankarmsy.github.io/posts/pca-sklearn.html#sthash.sam2ENZp.dpuf
# Out:
#   File "<ipython-input-25-f1020ec9b7f2>", line 1
#     fig = plt.figure(figsize=(8,8)) fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05) # plot the faces, each image is 64 by 64 pixels for i in range(10): ax = fig.add_subplot(5, 5, i+1, xticks=[], yticks=[]) ax.imshow(np.reshape(pca_oliv.components_[i,:], (64,64)), cmap=plt.cm.bone, interpolation='nearest') - See more at: https://shankarmsy.github.io/posts/pca-sklearn.html#sthash.sam2ENZp.dpuf
#                                       ^
# SyntaxError: invalid syntax
